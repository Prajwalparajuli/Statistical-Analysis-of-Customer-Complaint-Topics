# %% [markdown]
# ### Is there a statistically significant difference in the dispute rate between different topics of customer complaints?

# %%
import pandas as pd 

raw_complaints_df = pd.read_csv('complaints.csv', low_memory=False)

# %%
import numpy as np
raw_complaints_df.head(25)
# Out:
#    Date received                                            Product  \
# 0     2020-07-06  Credit reporting, credit repair services, or o...
# 1     2019-12-26                        Credit card or prepaid card
# 2     2020-05-08  Credit reporting, credit repair services, or o...
# 3     2025-07-28  Credit reporting or other personal consumer re...
# 4     2025-08-11  Credit reporting or other personal consumer re...
# 5     2024-01-05  Credit reporting or other personal consumer re...
# 6     2025-09-09  Credit reporting or other personal consumer re...
# 7     2025-09-11  Credit reporting or other personal consumer re...
# 8     2025-08-15  Credit reporting or other personal consumer re...
# 9     2025-09-04  Credit reporting or other personal consumer re...
# 10    2023-06-19  Credit reporting, credit repair services, or o...
# 11    2025-08-01                                    Debt collection
# 12    2025-08-11  Credit reporting or other personal consumer re...
# 13    2025-08-01  Credit reporting or other personal consumer re...
# 14    2020-06-25  Credit reporting, credit repair services, or o...
# 15    2025-08-26  Credit reporting or other personal consumer re...
# 16    2025-08-19  Credit reporting or other personal consumer re...
# 17    2025-08-04  Credit reporting or other personal consumer re...
# 18    2025-08-25  Credit reporting or other personal consumer re...
# 19    2025-08-08                                        Credit card
# 20    2025-08-25  Credit reporting or other personal consumer re...
# 21    2025-09-04  Credit reporting or other personal consumer re...
# 22    2025-08-03                                    Debt collection
# 23    2025-09-13  Credit reporting or other personal consumer re...
# 24    2025-08-08  Credit reporting or other personal consumer re...
#
#                                    Sub-product  \
# 0                             Credit reporting
# 1   General-purpose credit card or charge card
# 2                             Credit reporting
# 3                             Credit reporting
# 4                             Credit reporting
# 5                             Credit reporting
# 6                             Credit reporting
# 7                             Credit reporting
# 8                             Credit reporting
# 9                             Credit reporting
# 10                            Credit reporting
# 11                               I do not know
# 12                            Credit reporting
# 13                            Credit reporting
# 14                            Credit reporting
# 15                            Credit reporting
# 16                            Credit reporting
# 17                            Credit reporting
# 18                            Credit reporting
# 19  General-purpose credit card or charge card
# 20                            Credit reporting
# 21                            Credit reporting
# 22                               I do not know
# 23                            Credit reporting
# 24                            Credit reporting
#
#                                                 Issue  \
# 0                Incorrect information on your report
# 1   Advertising and marketing, including promotion...
# 2                Incorrect information on your report
# 3                Incorrect information on your report
# 4                Incorrect information on your report
# 5                Incorrect information on your report
# 6                         Improper use of your report
# 7                Incorrect information on your report
# 8                         Improper use of your report
# 9                Incorrect information on your report
# 10                        Improper use of your report
# 11                 False statements or representation
# 12  Problem with a company's investigation into an...
# 13               Incorrect information on your report
# 14  Problem with a credit reporting company's inve...
# 15  Problem with a company's investigation into an...
# 16               Incorrect information on your report
# 17               Incorrect information on your report
# 18  Problem with a company's investigation into an...
# 19                                   Fees or interest
# 20                        Improper use of your report
# 21               Incorrect information on your report
# 22                 False statements or representation
# 23               Incorrect information on your report
# 24               Incorrect information on your report
#
#                                             Sub-issue  \
# 0                 Information belongs to someone else
# 1   Confusing or misleading advertising about the ...
# 2                 Information belongs to someone else
# 3                            Account status incorrect
# 4                 Information belongs to someone else
# 5                 Information belongs to someone else
# 6       Reporting company used your report improperly
# 7                 Information belongs to someone else
# 8   Credit inquiries on your report that you don't...
# 9                            Account status incorrect
# 10      Reporting company used your report improperly
# 11                  Attempted to collect wrong amount
# 12  Their investigation did not fix an error on yo...
# 13                Information belongs to someone else
# 14  Their investigation did not fix an error on yo...
# 15  Their investigation did not fix an error on yo...
# 16                      Account information incorrect
# 17                Information belongs to someone else
# 18  Their investigation did not fix an error on yo...
# 19                                  Problem with fees
# 20  Credit inquiries on your report that you don't...
# 21                Information belongs to someone else
# 22                  Attempted to collect wrong amount
# 23                Information belongs to someone else
# 24                Information belongs to someone else
#
#                          Consumer complaint narrative  \
# 0                                                 NaN
# 1                                                 NaN
# 2                          These are not my accounts.
# 3                                                 NaN
# 4                                                 NaN
# 5   Kindly address this issue on my credit report....
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                               Company public response  \
# 0   Company has responded to the consumer and the ...
# 1                                                 NaN
# 2   Company has responded to the consumer and the ...
# 3                                                 NaN
# 4                                                 NaN
# 5   Company has responded to the consumer and the ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Company has responded to the consumer and the ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                                      Company State ZIP code Tags  \
# 0        Experian Information Solutions Inc.    FL    346XX  NaN
# 1          CAPITAL ONE FINANCIAL CORPORATION    CA    94025  NaN
# 2        Experian Information Solutions Inc.    NV    89030  NaN
# 3        Experian Information Solutions Inc.    TX    78232  NaN
# 4                              EQUIFAX, INC.    TX    77520  NaN
# 5        Experian Information Solutions Inc.    IL    60502  NaN
# 6                        ALLY FINANCIAL INC.    AL    36027  NaN
# 7                              EQUIFAX, INC.    AZ    85033  NaN
# 8          CAPITAL ONE FINANCIAL CORPORATION    IN    463XX  NaN
# 9                              EQUIFAX, INC.    AL    354XX  NaN
# 10       Experian Information Solutions Inc.    CA    92880  NaN
# 11                        EOS Holdings, Inc.    VA    24550  NaN
# 12    TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    76082  NaN
# 13                             EQUIFAX, INC.    FL    33033  NaN
# 14                             EQUIFAX, INC.    GA    30144  NaN
# 15       Experian Information Solutions Inc.    FL    34219  NaN
# 16                             EQUIFAX, INC.    AL    36607  NaN
# 17    TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX    75032  NaN
# 18                             EQUIFAX, INC.    PA    19540  NaN
# 19          HSBC NORTH AMERICA HOLDINGS INC.    CA    926XX  NaN
# 20    TRANSUNION INTERMEDIATE HOLDINGS, INC.    MD    20695  NaN
# 21    TRANSUNION INTERMEDIATE HOLDINGS, INC.    FL    33056  NaN
# 22  Consumer Adjustment Company Incorporated    IL    609XX  NaN
# 23                             EQUIFAX, INC.    TN    37040  NaN
# 24    TRANSUNION INTERMEDIATE HOLDINGS, INC.    OR    970XX  NaN
#
#    Consumer consent provided? Submitted via Date sent to company  \
# 0                       Other           Web           2020-07-06
# 1        Consent not provided           Web           2019-12-26
# 2            Consent provided           Web           2020-05-08
# 3                         NaN           Web           2025-07-28
# 4                         NaN           Web           2025-08-11
# 5            Consent provided           Web           2024-01-05
# 6                         NaN           Web           2025-09-10
# 7                         NaN           Web           2025-09-11
# 8                         NaN           Web           2025-08-15
# 9                         NaN           Web           2025-09-04
# 10       Consent not provided           Web           2023-06-19
# 11                        NaN           Web           2025-08-01
# 12                        NaN           Web           2025-08-11
# 13                        NaN           Web           2025-08-01
# 14       Consent not provided           Web           2020-06-25
# 15                        NaN           Web           2025-08-26
# 16                        NaN           Web           2025-08-19
# 17                        NaN           Web           2025-08-04
# 18                        NaN           Web           2025-08-25
# 19                        NaN           Web           2025-08-08
# 20                        NaN           Web           2025-08-25
# 21                        NaN           Web           2025-09-04
# 22                        NaN           Web           2025-08-03
# 23                        NaN           Web           2025-09-13
# 24                        NaN           Web           2025-08-09
#
#        Company response to consumer Timely response? Consumer disputed?  \
# 0           Closed with explanation              Yes                NaN
# 1           Closed with explanation              Yes                NaN
# 2           Closed with explanation              Yes                NaN
# 3                       In progress              Yes                NaN
# 4                       In progress              Yes                NaN
# 5   Closed with non-monetary relief              Yes                NaN
# 6                       In progress              Yes                NaN
# 7                       In progress              Yes                NaN
# 8   Closed with non-monetary relief              Yes                NaN
# 9                       In progress              Yes                NaN
# 10          Closed with explanation              Yes                NaN
# 11          Closed with explanation              Yes                NaN
# 12                      In progress              Yes                NaN
# 13                      In progress              Yes                NaN
# 14          Closed with explanation              Yes                NaN
# 15                      In progress              Yes                NaN
# 16                      In progress              Yes                NaN
# 17                      In progress              Yes                NaN
# 18                      In progress              Yes                NaN
# 19          Closed with explanation              Yes                NaN
# 20                      In progress              Yes                NaN
# 21                      In progress              Yes                NaN
# 22          Closed with explanation              Yes                NaN
# 23                      In progress              Yes                NaN
# 24                      In progress              Yes                NaN
#
#     Complaint ID
# 0        3730948
# 1        3477549
# 2        3642453
# 3       14934905
# 4       15211619
# 5        8113747
# 6       15813082
# 7       15886690
# 8       15305109
# 9       15684036
# 10       7139337
# 11      15011091
# 12      15203256
# 13      15040401
# 14       3716898
# 15      15535033
# 16      15383206
# 17      15071888
# 18      15506927
# 19      15178506
# 20      15486576
# 21      15713892
# 22      15019582
# 23      15923126
# 24      15161074

# %%
# Define and select the columns required for the analysis
required_cols = [
    'Product',
    'Consumer complaint narrative',
    'Consumer disputed?'
]
# Create a new, DataFrame for selected data
selected_complaints_df = raw_complaints_df[required_cols].copy()

# Drop rows that are missing either a narrative or a dispute status
selected_complaints_df.dropna(subset=['Consumer complaint narrative', 'Consumer disputed?'], inplace=True)

# Display the info and first 5 rows of the final, selected DataFrame
print("--- Selected DataFrame Info ---")
selected_complaints_df.info()
print("\n--- Head of Selected DataFrame ---")
selected_complaints_df.head()
# Out:
# --- Selected DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 164003 entries, 1978 to 11013727
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Product                       164003 non-null  object
#  1   Consumer complaint narrative  164003 non-null  object
#  2   Consumer disputed?            164003 non-null  object
# dtypes: object(3)
# memory usage: 5.0+ MB
#
# --- Head of Selected DataFrame ---
#               Product                       Consumer complaint narrative  \
# 1978         Mortgage  Caliber Home Loans has engaged in the prohibit...
# 2077         Mortgage  I have filed numerous complaints in an attempt...
# 2177  Debt collection  To Whom it may concern : Consumer Collection M...
# 2231      Credit card  I received a letter dated XXXX/XXXX/15 stating...
# 2500  Debt collection  In 2011 I purchase a new phone at a XXXX store...
#
#      Consumer disputed?
# 1978                 No
# 2077                 No
# 2177                 No
# 2231                Yes
# 2500                 No

# %% [markdown]
# Importing the NTLK Library (Natural Language Toolkit)
# - punkt = This splits a block of text into a list of individual words or sentences. The punkt model is very effective because it's been pre-trained to understand how to handle punctuation, abbreviations, and other complexities of the English language.
# - stopwords = Stopwords are very common words that carry little semantic meaning, such as 'a', 'the', 'is', 'in', and 'of'. These words are just noise in our case. The stopwords contains a standard list of English stopwords so we can filter them out of our complaint text later.
# - wordnet = WordNet is a large lexical database of English words, like a super-powered dictionary. We need it for Lemmatization, which is the process of reducing a word to its core dictionary form (its "lemma"). For example, with WordNet, we can correctly determine that the lemma for 'ran', 'runs', and 'running' is 'run'.

# %%
# --- NLTK SETUP CELL ---

import os
import nltk

# Define and add our local project's NLTK data path
local_data_path = os.path.join(os.getcwd(), 'nltk_data')
if not os.path.exists(local_data_path):
    os.makedirs(local_data_path)
if local_data_path not in nltk.data.path:
    nltk.data.path.append(local_data_path)

# Download all required packages, including the newly identified 'punkt_tab'
nltk.download('punkt', download_dir=local_data_path)
nltk.download('punkt_tab', download_dir=local_data_path) # The fix is here
nltk.download('stopwords', download_dir=local_data_path)
nltk.download('wordnet', download_dir=local_data_path)

print("SUCCESS: All NLTK packages have been downloaded and configured for this project.")
# Out:
# SUCCESS: All NLTK packages have been downloaded and configured for this project.
# [nltk_data] Downloading package punkt to c:\Users\prajw\Desktop\NLP
# [nltk_data]     project\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     c:\Users\prajw\Desktop\NLP project\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     c:\Users\prajw\Desktop\NLP project\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to c:\Users\prajw\Desktop\NLP
# [nltk_data]     project\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Preprocessing

# %%
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Define a function to preprocess the text
def preprocess_text(text):
    # 1. Lowercase the text
    text = text.lower()

    # 2. Tokenize the text into words
    tokens = word_tokenize(text)

    # 3. Lemmatization & Stopword/Punctuation Removal
    lemmatizer = WordNetLemmatizer()
    cleaned_tokens = [
        lemmatizer.lemmatize(token) 
        for token in tokens 
        if token not in stopwords.words('english') and token not in string.punctuation
    ]
    return cleaned_tokens 


# --- Tests the function on an example sentence ---
example_text = "I was charged multiple fees for my mortgage payments, which is frustrating!"
processed_example = preprocess_text(example_text)

print(f"Original Text:\n{example_text}\n")
print(f"Processed Tokens:\n{processed_example}")
# Out:
# Original Text:
# I was charged multiple fees for my mortgage payments, which is frustrating!
#
# Processed Tokens:
# ['charged', 'multiple', 'fee', 'mortgage', 'payment', 'frustrating']

# %%
print("Applying the pre-processing function to the DataFrame...")
print("This may take several minutes to complete...")

# Apply the function to each item in the 'Consumer complaint narrative' column
selected_complaints_df['cleaned_tokens'] = selected_complaints_df['Consumer complaint narrative'].apply(preprocess_text)

print("\nProcessing complete.")
print("Here is the head of the updated DataFrame:")

# Display the first 5 rows to show the new column
selected_complaints_df.head()
# Out:
# Applying the pre-processing function to the DataFrame...
# This may take several minutes to complete...
#
# Processing complete.
# Here is the head of the updated DataFrame:
#               Product                       Consumer complaint narrative  \
# 1978         Mortgage  Caliber Home Loans has engaged in the prohibit...
# 2077         Mortgage  I have filed numerous complaints in an attempt...
# 2177  Debt collection  To Whom it may concern : Consumer Collection M...
# 2231      Credit card  I received a letter dated XXXX/XXXX/15 stating...
# 2500  Debt collection  In 2011 I purchase a new phone at a XXXX store...
#
#      Consumer disputed?                                     cleaned_tokens
# 1978                 No  [caliber, home, loan, engaged, prohibited, pat...
# 2077                 No  [filed, numerous, complaint, attempt, stop, na...
# 2177                 No  [may, concern, consumer, collection, managemen...
# 2231                Yes  [received, letter, dated, xxxx/xxxx/15, statin...
# 2500                 No  [2011, purchase, new, phone, xxxx, store, xxxx...

# %%
# --- Save the Processed Data ---
print("Saving the processed DataFrame to a file...")

output_file_path = "processed_complaints.pkl"
selected_complaints_df.to_pickle(output_file_path)

print(f"DataFrame successfully saved to: {output_file_path}")
# Out:
# Saving the processed DataFrame to a file...
# DataFrame successfully saved to: processed_complaints.pkl
